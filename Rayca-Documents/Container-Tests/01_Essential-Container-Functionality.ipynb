# %% [markdown]
# # 01 - Essential Container Functionality Test
# Date: 2025-11-16
#
# This notebook tests the basic functionality of the Germinal Docker container.
# Run this notebook inside the container to verify all dependencies are properly installed.

# %% [markdown]
# ## 1. Python Environment Check

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# %% [markdown]
# ## 2. Core Scientific Packages

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib
import biopython
from Bio import __version__ as bio_version

print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"SciPy: {scipy.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Biopython: {bio_version}")

# %% [markdown]
# ## 3. GPU and CUDA Check

# %%
import subprocess
result = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
print("NVIDIA GPU Info:")
print(result.stdout)

# %% [markdown]
# ## 4. JAX Backend Verification

# %%
import jax
import jax.numpy as jnp

print(f"JAX version: {jax.__version__}")
print(f"JAX backend: {jax.default_backend()}")
print(f"JAX devices: {jax.devices()}")

# Test GPU computation
x = jnp.ones((1000, 1000))
y = jnp.dot(x, x)
print(f"JAX GPU computation test passed. Result shape: {y.shape}")

# %% [markdown]
# ## 5. PyTorch Check

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# %% [markdown]
# ## 6. PyRosetta Initialization

# %%
import pyrosetta as pr

# Initialize PyRosetta (minimal init for testing)
pr.init("-mute all")
print(f"PyRosetta initialized successfully")
print(f"PyRosetta version: {pr.rosetta.utility.Version.version()}")

# %% [markdown]
# ## 7. ColabDesign Import

# %%
import colabdesign
from colabdesign import mk_afdesign_model

print(f"ColabDesign imported successfully")
print(f"ColabDesign location: {colabdesign.__file__}")

# %% [markdown]
# ## 8. Germinal Package Import

# %%
import germinal
from germinal.design.design import germinal_design
from germinal.filters import filter_utils, redesign
from germinal.utils import utils, config

print(f"Germinal package imported successfully")
print(f"Germinal location: {germinal.__file__}")

# %% [markdown]
# ## 9. IgLM and Chai-lab

# %%
import iglm
import chai_lab

print(f"IgLM imported successfully")
print(f"Chai-lab imported successfully")

# %% [markdown]
# ## 10. Hydra Configuration System

# %%
import hydra
from omegaconf import OmegaConf

print(f"Hydra version: {hydra.__version__}")
print(f"OmegaConf version: {OmegaConf.__version__}")

# %% [markdown]
# ## 11. AlphaFold Parameters Check

# %%
import os

params_dir = "/workspace/params"
if os.path.exists(params_dir):
    params_files = os.listdir(params_dir)
    print(f"AlphaFold parameters directory: {params_dir}")
    print(f"Number of files/dirs: {len(params_files)}")
    print(f"Contents: {params_files[:10]}...") if len(params_files) > 10 else print(f"Contents: {params_files}")
else:
    print(f"ERROR: Parameters directory not found at {params_dir}")

# %% [markdown]
# ## Summary

# %%
print("=" * 50)
print("ESSENTIAL CONTAINER FUNCTIONALITY TEST COMPLETE")
print("=" * 50)
print("\nAll critical components verified:")
print("✓ Python environment")
print("✓ Core scientific packages")
print("✓ GPU/CUDA access")
print("✓ JAX with GPU backend")
print("✓ PyTorch with CUDA")
print("✓ PyRosetta")
print("✓ ColabDesign")
print("✓ Germinal package")
print("✓ IgLM and Chai-lab")
print("✓ Hydra configuration")
print("✓ AlphaFold parameters")
